# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dati = pd.read_csv("articles.csv")
dati
# Out:
#         article_id  product_code               prod_name  product_type_no  \
# 0        108775015        108775               Strap top              253
# 1        108775044        108775               Strap top              253
# 2        108775051        108775           Strap top (1)              253
# 3        110065001        110065       OP T-shirt (Idro)              306
# 4        110065002        110065       OP T-shirt (Idro)              306
# ...            ...           ...                     ...              ...
# 105537   953450001        953450  5pk regular Placement1              302
# 105538   953763001        953763       SPORT Malaga tank              253
# 105539   956217002        956217         Cartwheel dress              265
# 105540   957375001        957375        CLAIRE HAIR CLAW               72
# 105541   959461001        959461            Lounge dress              265
#
#        product_type_name  product_group_name  graphical_appearance_no  \
# ...

# %%
dati.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  object
#  3   product_type_no               105542 non-null  int64
#  4   product_type_name             105542 non-null  object
#  5   product_group_name            105542 non-null  object
#  6   graphical_appearance_no       105542 non-null  int64
#  7   graphical_appearance_name     105542 non-null  object
#  8   colour_group_code             105542 non-null  int64
#  9   colour_group_name             105542 non-null  object
#  10  perceived_colour_value_id     105542 non-null  int64
#  11  perceived_colour_value_name   105542 non-null  object
# ...

# %%
dati.dropna(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(10,10))
dati["colour_group_name"].hist(ax = ax, xrot=90)
plt.show()

# %%
dati["product_type_name"] = dati["product_type_name"].str.lower() # metto tutti i caratteri minuscoli

tipi_vestiti = dati["product_type_name"].unique() # guardo i tipi di vestiti

tipi_vestiti_stringhe = tipi_vestiti.astype(str) # converto array da tipo object a str

tipi_vestiti_pantaloni_indici = np.flatnonzero(np.core.defchararray.find(tipi_vestiti_stringhe, "trousers")!=-1) # restituisco gli indici delle celle contenenti la sottostringa trousers

tipi_vestiti_pantaloni = tipi_vestiti_stringhe[tipi_vestiti_pantaloni_indici] # tipi di pantaloni
tipi_vestiti_pantaloni
# Out:
# array(['trousers', 'outdoor trousers'], dtype='<U24')

# %%
pantaloni = dati[dati['product_type_name'].isin(tipi_vestiti_pantaloni)] # guardo i vestiti con quei determinati product_type_name
pantaloni
# Out:
#         article_id  product_code                  prod_name  product_type_no  \
# 16       118458003        118458       Jerry jogger bottoms              272
# 17       118458004        118458       Jerry jogger bottoms              272
# 18       118458028        118458       Jerry jogger bottoms              272
# 19       118458029        118458       Jerry jogger bottoms              272
# 20       118458034        118458       Jerry jogger bottoms              272
# ...            ...           ...                        ...              ...
# 105386   939549002        939549             Bug sweatpants              272
# 105387   939549003        939549             Bug sweatpants              272
# 105471   943097001        943097  Sandra HW Wide Trousers 1              272
# 105528   949198001        949198            Saturday jogger              272
# 105532   949594001        949594         LOGG Elvis jogger.              272
#
# ...

# %%
pantaloni_colori = pantaloni["colour_group_name"].values
unique, frequency = np.unique(pantaloni_colori, 
                              return_counts = True)
# print unique values array
print("Unique Values:", unique)
  
# print frequency array
print("Frequency Values:",frequency)

n = frequency.min()

posizione_n = frequency == n

unique[posizione_n][0]
# Out:
# Unique Values: ['Beige' 'Black' 'Blue' 'Bronze/Copper' 'Dark Beige' 'Dark Blue'
#  'Dark Green' 'Dark Grey' 'Dark Orange' 'Dark Pink' 'Dark Purple'
#  'Dark Red' 'Dark Turquoise' 'Dark Yellow' 'Gold' 'Green' 'Greenish Khaki'
#  'Grey' 'Greyish Beige' 'Light Beige' 'Light Blue' 'Light Green'
#  'Light Grey' 'Light Orange' 'Light Pink' 'Light Purple' 'Light Red'
#  'Light Turquoise' 'Light Yellow' 'Off White' 'Orange' 'Other'
#  'Other Blue' 'Other Orange' 'Other Pink' 'Other Red' 'Other Yellow'
#  'Pink' 'Purple' 'Red' 'Silver' 'Transparent' 'Turquoise' 'Unknown'
#  'White' 'Yellow' 'Yellowish Brown']
# Frequency Values: [ 305 2765 1106    1  198 2040  198  531   58   47   16  179   39   49
#     1   64  523  507   27  280  689   33  224   33  225   19   15   54
#    21  181   18   11    7    3   26    5    1   95    2  109    5    2
#    21   14  310   62  151]
# 'Bronze/Copper'

# %% [markdown]
# Utilizzando il dataset degli articoli di H&M creare un grafico della distribuzione di colore per ogni tipologia di index_group (colonna index_group_name). C'è un legame tra la distribuzione di colore e l'index_group?

# %%
dati[(dati["index_group_name"] == tipo)]["colour_group_name"].value_counts()
# Out:
# Black              4674
# White              1330
# Light Pink          746
# Dark Blue           706
# Blue                697
# Red                 606
# Beige               544
# Light Blue          527
# Greenish Khaki      481
# Grey                438
# Pink                387
# Light Beige         371
# Yellow              329
# Off White           319
# Dark Red            310
# Dark Grey           281
# Light Grey          252
# Dark Green          223
# Light Orange        204
# Dark Pink           196
# Light Purple        172
# Light Yellow        136
# Green               115
# Light Turquoise      97
# Light Green          95
# Orange               88
# Silver               85
# Dark Beige           76
# Gold                 66
# Dark Yellow          64
# Yellowish Brown      64
# Other Yellow         62
# Turquoise            55
# Dark Orange          54
# Other Pink           50
# Purple               36
# Dark Purple          35
# Other Orange         27
# ...

# %%
fig, axs = plt.subplots(nrows=len(dati["index_group_name"].unique()),figsize=(30,30))
for i, tipo in enumerate(dati["index_group_name"].unique()):
    dati[(dati["index_group_name"] == tipo)]["colour_group_name"].value_counts().plot.bar(ax = axs[i], title=tipo)
plt.show()
