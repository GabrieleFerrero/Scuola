# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dati_covid = pd.read_csv("/home/gabriele/Scaricati/Untitled Folder/dati.csv")
dati_covid
# Out:
#                     data stato  ricoverati_con_sintomi  terapia_intensiva  \
# 0    2020-02-24T18:00:00   ITA                     101                 26
# 1    2020-02-25T18:00:00   ITA                     114                 35
# 2    2020-02-26T18:00:00   ITA                     128                 36
# 3    2020-02-27T18:00:00   ITA                     248                 56
# 4    2020-02-28T18:00:00   ITA                     345                 64
# ..                   ...   ...                     ...                ...
# 685  2022-01-09T17:00:00   ITA                   15647               1595
# 686  2022-01-10T17:00:00   ITA                   16340               1606
# 687  2022-01-11T17:00:00   ITA                   17067               1677
# 688  2022-01-12T17:00:00   ITA                   17309               1669
# 689  2022-01-13T17:00:00   ITA                   17648               1668
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# ...

# %%
fig, ax = plt.subplots(figsize=(40,20))
ax.plot(dati_covid["terapia_intensiva"].values, "r", label="Terapia Intensiva")
ax.plot(dati_covid["totale_ospedalizzati"].values, "b", label="Totale Ospedalizzati")
ax.plot(dati_covid["ricoverati_con_sintomi"].values, "m", label="Ricoverati con Sintomi")
plt.legend(prop={"size":30})
plt.show()
